# %% [markdown]
# # Quick data visualization

# %%
# display some images for every different expression

import numpy as np
import seaborn as sns
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import os

# size of the image: 48*48 pixels
pic_size = 48

# input path for the images
base_path = "input2/"

plt.figure(0, figsize=(12,20))
cpt = 0

for expression in os.listdir(base_path + "train/"):
    for i in range(1,6):
        cpt = cpt + 1
        plt.subplot(7,5,cpt)
        img = load_img(base_path + "train/" + expression + "/" +os.listdir(base_path + "train/" + expression)[i], target_size=(pic_size, pic_size))
        plt.imshow(img, cmap="gray")

plt.tight_layout()
plt.show()

# %%
# count number of train images for each expression

for expression in os.listdir(base_path + "train"):
    print(str(len(os.listdir(base_path + "train/" + expression))) + " " + expression + " images")
# Out:
# 3993 angry images
# 436 disgust images
# 4103 fear images
# 7164 happy images
# 4982 neutral images
# 4938 sad images
# 3205 surprise images

# %% [markdown]
# The image expressions in our training dataset are pretty balanced, except for the 'disgust' category.

# %% [markdown]
# # Setup the data generators

# %%
from keras.preprocessing.image import ImageDataGenerator

# number of images to feed into the NN for every batch
batch_size = 128

datagen_train = ImageDataGenerator()
datagen_validation = ImageDataGenerator()
datagen_test = ImageDataGenerator()

train_generator = datagen_train.flow_from_directory(base_path + "train",
                                                    target_size=(pic_size,pic_size),
                                                    color_mode="grayscale",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=True)

validation_generator = datagen_validation.flow_from_directory(base_path + "validation",
                                                    target_size=(pic_size,pic_size),
                                                    color_mode="grayscale",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=False)

test_generator = datagen_test.flow_from_directory(base_path + "test",
                                                    target_size=(pic_size,pic_size),
                                                    color_mode="grayscale",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=False)
# Out:
# Found 28821 images belonging to 7 classes.
# Found 7066 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# # Setup our Convolutional Neural Network (CNN)
#
# We chose to use a Convolutional Neural Network in order to tackle this face recognition problem. Indeed this type of Neural Network (NN) is good for extracting the features of images and is widely used for image analysis subjects like image classification.
#
# **Quick reminder of what a NN is:**
#
# A Neural Network is a learning framework that consists in multiple layers of artificial neurons (nodes). Each node gets weighted input data, passes it into an activation function and outputs the result of the function:
#
# ![](https://skymind.ai/images/wiki/perceptron_node.png)
#
# A NN is composed of several layers of nodes:
#
# ![](https://www.researchgate.net/profile/Martin_Musiol/publication/308414212/figure/fig1/AS:409040078295040@1474534162122/A-general-model-of-a-deep-neural-network-It-consists-of-an-input-layer-some-here-two.png)
#
# - An input layer that will get the data. The size of the input layer depends on the size of the input data.
# - Some hidden layers that will allow the NN to learn complex interactions within the data. A Neural Network with a lot of hidden layers is called a Deep Neural Network.
# - An output layer that will give the final result, for instance a class prediction. The size of this layer depends on the type of output we want to produce (e.g. how many classes do we want to predict?)
#
# Classic NNs are usually composed of several fully connected layers. This means that every neuron of one layer is connected to every neurons of the next layer.
#
# Convolutional Neural Networks also have Convolutional layers that apply sliding functions to group of pixels that are next to each other. Therefore those structures have a better understanding of patterns that we can observe in images. We will explain this in more details after.
#
# Now let's define the architecture of our CNN:

# %%
from keras.layers import Dense, Input, Dropout, GlobalAveragePooling2D, Flatten, Conv2D, BatchNormalization, Activation, MaxPooling2D
from keras.models import Model, Sequential
from keras.optimizers import Adam

# number of possible label values
nb_classes = 7

# Initialising the CNN
model = Sequential()

# 1 - Convolution
model.add(Conv2D(64,(3,3), padding='same', input_shape=(48, 48,1)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# 2nd Convolution layer
model.add(Conv2D(128,(5,5), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# 3rd Convolution layer
model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# 4th Convolution layer
model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Flattening
model.add(Flatten())

# Fully connected layer 1st layer
model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

# Fully connected layer 2nd layer
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Dense(nb_classes, activation='softmax'))

opt = Adam(lr=0.0001)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 64)        640
#
#  batch_normalization (BatchN  (None, 48, 48, 64)       256
#  ormalization)
#
#  activation (Activation)     (None, 48, 48, 64)        0
#
#  max_pooling2d (MaxPooling2D  (None, 24, 24, 64)       0
#  )
#
#  dropout (Dropout)           (None, 24, 24, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 128)       204928
#
#  batch_normalization_1 (Batc  (None, 24, 24, 128)      512
#  hNormalization)
#
#  activation_1 (Activation)   (None, 24, 24, 128)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 12, 12, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 512)       590336
#
#  batch_normalization_2 (Batc  (None, 12, 12, 512)      2048
#  hNormalization)
#
#  activation_2 (Activation)   (None, 12, 12, 512)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 512)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 6, 6, 512)         0
#
#  conv2d_3 (Conv2D)           (None, 6, 6, 512)         2359808
#
#  batch_normalization_3 (Batc  (None, 6, 6, 512)        2048
#  hNormalization)
#
#  activation_3 (Activation)   (None, 6, 6, 512)         0
#
#  max_pooling2d_3 (MaxPooling  (None, 3, 3, 512)        0
#  2D)
#
#  dropout_3 (Dropout)         (None, 3, 3, 512)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 256)               1179904
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 512)               131584
#
#  batch_normalization_5 (Batc  (None, 512)              2048
#  hNormalization)
#
#  activation_5 (Activation)   (None, 512)               0
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 4,478,727
# Trainable params: 4,474,759
# Non-trainable params: 3,968
# _________________________________________________________________
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\optimizers\legacy\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %% [markdown]
# We define our CNN with the following global architecture:
# - 4 convolutional layers
# - 2 fully connected layers
#
# The convolutional layers will extract relevant features from the images and the fully connected layers will focus on using these features to classify well our images. This architecture was inspired by the following work on the subject: https://github.com/jrishabh96/Facial-Expression-Recognition
#
# Let's focus on how our convolution layers work. Each of them contain the following operations:
# - A convolution operator: extracts features from the input image using sliding matrices to preserve the spatial relations between the pixels. The following image summarizes how it works:
# ![](http://deeplearning.stanford.edu/wiki/images/6/6c/Convolution_schematic.gif)
#
# The green matrix corresponds to the raw image values. The orange sliding matrix is called a 'filter' or 'kernel'. This filter slides over the image by one pixel at each step (stride). During each step, we multiply the filter with the corresponding elements of the base matrix. There are different types of filters and each one will be able to retrieve different image features:
# ![](https://ujwlkarn.files.wordpress.com/2016/08/screen-shot-2016-08-05-at-11-03-00-pm.png?w=342&h=562)
#
# - We apply the ReLU function to introduce non linearity in our CNN. Other functions like tanh or sigmoid could also be used, but ReLU has been found to perform better in most situations.
# - Pooling is used to reduce the dimensionality of each features while retaining the most important information. Like for the convolutional step, we apply a sliding function on our data. Different functions can be applied: max, sum, mean... The max function usually performs better.
# ![](http://cs231n.github.io/assets/cnn/maxpool.jpeg)
#
# We also use some common techniques for each layer:
# - Batch normalization: improves the performance and stability of NNs by providing inputs with zero mean and unit variance.
# - Dropout: reduces overfitting by randomly not updating the weights of some nodes. This helps prevent the NN from relying on one node in the layer too much.
#
# We chose softmax as our last activation function as it is commonly used for multi-label classification.
#
# Now that our CNN is defined, we can compile it with a few more parameters. We chose the Adam optimizer as it is one of the most computationally effective. We chose the categorical cross-entropy as our loss function as it is quite relevant for classification tasks. Our metric will be the accuracy, which is also quite informative for classification tasks on balanced datasets.

# %% [markdown]
# # Train the model

# %% [markdown]
# Everything is set up, let's train our model now!

# %%
# %%time

# number of epochs to train the NN
epochs = 80

from keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint("model_weights2.h5", monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

history = model.fit_generator(generator=train_generator,
                                steps_per_epoch=train_generator.n//train_generator.batch_size,
                                epochs=epochs,
                                validation_data = validation_generator,
                                validation_steps = validation_generator.n//validation_generator.batch_size,
                                callbacks=callbacks_list
                                )
# Out:
# <timed exec>:9: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/80
# 225/225 [==============================] - ETA: 0s - loss: 2.0465 - accuracy: 0.2265WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1344s 6s/step - loss: 2.0465 - accuracy: 0.2265 - val_loss: 1.7265 - val_accuracy: 0.3115
# Epoch 2/80
# 225/225 [==============================] - ETA: 0s - loss: 1.8305 - accuracy: 0.2915WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1270s 6s/step - loss: 1.8305 - accuracy: 0.2915 - val_loss: 1.7142 - val_accuracy: 0.3347
# Epoch 3/80
# 225/225 [==============================] - ETA: 0s - loss: 1.7290 - accuracy: 0.3326WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1239s 6s/step - loss: 1.7290 - accuracy: 0.3326 - val_loss: 1.6706 - val_accuracy: 0.3662
# Epoch 4/80
# 225/225 [==============================] - ETA: 0s - loss: 1.6410 - accuracy: 0.3697WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1148s 5s/step - loss: 1.6410 - accuracy: 0.3697 - val_loss: 1.5942 - val_accuracy: 0.3939
# Epoch 5/80
# 225/225 [==============================] - ETA: 0s - loss: 1.5948 - accuracy: 0.3861WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1151s 5s/step - loss: 1.5948 - accuracy: 0.3861 - val_loss: 1.5799 - val_accuracy: 0.4061
# Epoch 6/80
# 225/225 [==============================] - ETA: 0s - loss: 1.5409 - accuracy: 0.4076WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1233s 5s/step - loss: 1.5409 - accuracy: 0.4076 - val_loss: 1.4934 - val_accuracy: 0.4287
# Epoch 7/80
# 225/225 [==============================] - ETA: 0s - loss: 1.4893 - accuracy: 0.4283WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1250s 6s/step - loss: 1.4893 - accuracy: 0.4283 - val_loss: 1.4146 - val_accuracy: 0.4584
# Epoch 8/80
# 225/225 [==============================] - ETA: 0s - loss: 1.4453 - accuracy: 0.4423WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1148s 5s/step - loss: 1.4453 - accuracy: 0.4423 - val_loss: 1.4589 - val_accuracy: 0.4472
# Epoch 9/80
# 225/225 [==============================] - ETA: 0s - loss: 1.4042 - accuracy: 0.4589WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1149s 5s/step - loss: 1.4042 - accuracy: 0.4589 - val_loss: 1.5131 - val_accuracy: 0.4501
# Epoch 10/80
# 225/225 [==============================] - ETA: 0s - loss: 1.3719 - accuracy: 0.4719WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1160s 5s/step - loss: 1.3719 - accuracy: 0.4719 - val_loss: 1.2885 - val_accuracy: 0.5124
# Epoch 11/80
# 225/225 [==============================] - ETA: 0s - loss: 1.3345 - accuracy: 0.4898WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1148s 5s/step - loss: 1.3345 - accuracy: 0.4898 - val_loss: 1.3203 - val_accuracy: 0.5016
# Epoch 12/80
# 225/225 [==============================] - ETA: 0s - loss: 1.3047 - accuracy: 0.5002WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1152s 5s/step - loss: 1.3047 - accuracy: 0.5002 - val_loss: 1.2801 - val_accuracy: 0.5145
# Epoch 13/80
# 225/225 [==============================] - ETA: 0s - loss: 1.2751 - accuracy: 0.5094WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1151s 5s/step - loss: 1.2751 - accuracy: 0.5094 - val_loss: 1.2305 - val_accuracy: 0.5288
# Epoch 14/80
# 225/225 [==============================] - ETA: 0s - loss: 1.2514 - accuracy: 0.5211WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1151s 5s/step - loss: 1.2514 - accuracy: 0.5211 - val_loss: 1.2845 - val_accuracy: 0.5192
# Epoch 15/80
# 225/225 [==============================] - ETA: 0s - loss: 1.2245 - accuracy: 0.5335WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1154s 5s/step - loss: 1.2245 - accuracy: 0.5335 - val_loss: 1.1836 - val_accuracy: 0.5536
# Epoch 16/80
# 225/225 [==============================] - ETA: 0s - loss: 1.2026 - accuracy: 0.5405WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1149s 5s/step - loss: 1.2026 - accuracy: 0.5405 - val_loss: 1.1714 - val_accuracy: 0.5553
# Epoch 17/80
# 225/225 [==============================] - ETA: 0s - loss: 1.1828 - accuracy: 0.5457WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1151s 5s/step - loss: 1.1828 - accuracy: 0.5457 - val_loss: 1.1586 - val_accuracy: 0.5599
# Epoch 18/80
# 225/225 [==============================] - ETA: 0s - loss: 1.1592 - accuracy: 0.5557WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1151s 5s/step - loss: 1.1592 - accuracy: 0.5557 - val_loss: 1.1555 - val_accuracy: 0.5685
# Epoch 19/80
# 225/225 [==============================] - ETA: 0s - loss: 1.1477 - accuracy: 0.5617WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1151s 5s/step - loss: 1.1477 - accuracy: 0.5617 - val_loss: 1.1504 - val_accuracy: 0.5577
# Epoch 20/80
# 225/225 [==============================] - ETA: 0s - loss: 1.1260 - accuracy: 0.5722WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1153s 5s/step - loss: 1.1260 - accuracy: 0.5722 - val_loss: 1.1301 - val_accuracy: 0.5636
# Epoch 21/80
# 225/225 [==============================] - ETA: 0s - loss: 1.1088 - accuracy: 0.5793WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1147s 5s/step - loss: 1.1088 - accuracy: 0.5793 - val_loss: 1.1270 - val_accuracy: 0.5697
# Epoch 22/80
# 225/225 [==============================] - ETA: 0s - loss: 1.0932 - accuracy: 0.5864WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1151s 5s/step - loss: 1.0932 - accuracy: 0.5864 - val_loss: 1.1233 - val_accuracy: 0.5828
# Epoch 23/80
# 225/225 [==============================] - ETA: 0s - loss: 1.0724 - accuracy: 0.5928WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1158s 5s/step - loss: 1.0724 - accuracy: 0.5928 - val_loss: 1.1007 - val_accuracy: 0.5884
# Epoch 24/80
# 225/225 [==============================] - ETA: 0s - loss: 1.0542 - accuracy: 0.6010WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1153s 5s/step - loss: 1.0542 - accuracy: 0.6010 - val_loss: 1.1167 - val_accuracy: 0.5911
# Epoch 25/80
# 225/225 [==============================] - ETA: 0s - loss: 1.0415 - accuracy: 0.6081WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1150s 5s/step - loss: 1.0415 - accuracy: 0.6081 - val_loss: 1.0817 - val_accuracy: 0.5994
# Epoch 26/80
# 225/225 [==============================] - ETA: 0s - loss: 1.0183 - accuracy: 0.6195WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1295s 6s/step - loss: 1.0183 - accuracy: 0.6195 - val_loss: 1.1077 - val_accuracy: 0.5862
# Epoch 27/80
# 225/225 [==============================] - ETA: 0s - loss: 1.0093 - accuracy: 0.6207WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1191s 5s/step - loss: 1.0093 - accuracy: 0.6207 - val_loss: 1.1328 - val_accuracy: 0.5786
# Epoch 28/80
# 225/225 [==============================] - ETA: 0s - loss: 0.9900 - accuracy: 0.6273WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1184s 5s/step - loss: 0.9900 - accuracy: 0.6273 - val_loss: 1.1022 - val_accuracy: 0.5983
# Epoch 29/80
# 225/225 [==============================] - ETA: 0s - loss: 0.9748 - accuracy: 0.6334WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1197s 5s/step - loss: 0.9748 - accuracy: 0.6334 - val_loss: 1.0503 - val_accuracy: 0.6129
# Epoch 30/80
# 225/225 [==============================] - ETA: 0s - loss: 0.9610 - accuracy: 0.6378WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1168s 5s/step - loss: 0.9610 - accuracy: 0.6378 - val_loss: 1.0434 - val_accuracy: 0.6197
# Epoch 31/80
# 225/225 [==============================] - ETA: 0s - loss: 0.9483 - accuracy: 0.6434WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1186s 5s/step - loss: 0.9483 - accuracy: 0.6434 - val_loss: 1.0528 - val_accuracy: 0.6143
# Epoch 32/80
# 225/225 [==============================] - ETA: 0s - loss: 0.9309 - accuracy: 0.6508WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1163s 5s/step - loss: 0.9309 - accuracy: 0.6508 - val_loss: 1.0615 - val_accuracy: 0.6148
# Epoch 33/80
# 225/225 [==============================] - ETA: 0s - loss: 0.9132 - accuracy: 0.6563WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1166s 5s/step - loss: 0.9132 - accuracy: 0.6563 - val_loss: 1.0526 - val_accuracy: 0.6232
# Epoch 34/80
# 225/225 [==============================] - ETA: 0s - loss: 0.9017 - accuracy: 0.6612WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1160s 5s/step - loss: 0.9017 - accuracy: 0.6612 - val_loss: 1.0525 - val_accuracy: 0.6210
# Epoch 35/80
# 225/225 [==============================] - ETA: 0s - loss: 0.8888 - accuracy: 0.6647WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1158s 5s/step - loss: 0.8888 - accuracy: 0.6647 - val_loss: 1.0436 - val_accuracy: 0.6264
# Epoch 36/80
# 225/225 [==============================] - ETA: 0s - loss: 0.8642 - accuracy: 0.6770WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1165s 5s/step - loss: 0.8642 - accuracy: 0.6770 - val_loss: 1.0484 - val_accuracy: 0.6165
# Epoch 37/80
# 225/225 [==============================] - ETA: 0s - loss: 0.8511 - accuracy: 0.6805WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1168s 5s/step - loss: 0.8511 - accuracy: 0.6805 - val_loss: 1.1515 - val_accuracy: 0.6016
# Epoch 38/80
# 225/225 [==============================] - ETA: 0s - loss: 0.8404 - accuracy: 0.6865WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1165s 5s/step - loss: 0.8404 - accuracy: 0.6865 - val_loss: 1.0259 - val_accuracy: 0.6339
# Epoch 39/80
# 225/225 [==============================] - ETA: 0s - loss: 0.8272 - accuracy: 0.6902WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1243s 6s/step - loss: 0.8272 - accuracy: 0.6902 - val_loss: 1.0554 - val_accuracy: 0.6283
# Epoch 40/80
# 225/225 [==============================] - ETA: 0s - loss: 0.8046 - accuracy: 0.7000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1271s 6s/step - loss: 0.8046 - accuracy: 0.7000 - val_loss: 1.0639 - val_accuracy: 0.6240
# Epoch 41/80
# 225/225 [==============================] - ETA: 0s - loss: 0.7973 - accuracy: 0.7032WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1169s 5s/step - loss: 0.7973 - accuracy: 0.7032 - val_loss: 1.0276 - val_accuracy: 0.6357
# Epoch 42/80
# 225/225 [==============================] - ETA: 0s - loss: 0.7719 - accuracy: 0.7109WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1211s 5s/step - loss: 0.7719 - accuracy: 0.7109 - val_loss: 1.0400 - val_accuracy: 0.6357
# Epoch 43/80
# 225/225 [==============================] - ETA: 0s - loss: 0.7604 - accuracy: 0.7143WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1168s 5s/step - loss: 0.7604 - accuracy: 0.7143 - val_loss: 1.0277 - val_accuracy: 0.6418
# Epoch 44/80
# 225/225 [==============================] - ETA: 0s - loss: 0.7521 - accuracy: 0.7185WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1167s 5s/step - loss: 0.7521 - accuracy: 0.7185 - val_loss: 1.0663 - val_accuracy: 0.6379
# Epoch 45/80
# 225/225 [==============================] - ETA: 0s - loss: 0.7336 - accuracy: 0.7216WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1165s 5s/step - loss: 0.7336 - accuracy: 0.7216 - val_loss: 1.0298 - val_accuracy: 0.6379
# Epoch 46/80
# 225/225 [==============================] - ETA: 0s - loss: 0.7259 - accuracy: 0.7290WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1168s 5s/step - loss: 0.7259 - accuracy: 0.7290 - val_loss: 1.0421 - val_accuracy: 0.6446
# Epoch 47/80
# 225/225 [==============================] - ETA: 0s - loss: 0.7079 - accuracy: 0.7325WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1162s 5s/step - loss: 0.7079 - accuracy: 0.7325 - val_loss: 1.0708 - val_accuracy: 0.6470
# Epoch 48/80
# 225/225 [==============================] - ETA: 0s - loss: 0.6882 - accuracy: 0.7432WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1156s 5s/step - loss: 0.6882 - accuracy: 0.7432 - val_loss: 1.0813 - val_accuracy: 0.6357
# Epoch 49/80
# 225/225 [==============================] - ETA: 0s - loss: 0.6817 - accuracy: 0.7477WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1157s 5s/step - loss: 0.6817 - accuracy: 0.7477 - val_loss: 1.0419 - val_accuracy: 0.6359
# Epoch 50/80
# 225/225 [==============================] - ETA: 0s - loss: 0.6621 - accuracy: 0.7533WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1287s 6s/step - loss: 0.6621 - accuracy: 0.7533 - val_loss: 1.0567 - val_accuracy: 0.6369
# Epoch 51/80
# 225/225 [==============================] - ETA: 0s - loss: 0.6516 - accuracy: 0.7564WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1234s 5s/step - loss: 0.6516 - accuracy: 0.7564 - val_loss: 1.0960 - val_accuracy: 0.6358
# Epoch 52/80
# 225/225 [==============================] - ETA: 0s - loss: 0.6423 - accuracy: 0.7568WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1167s 5s/step - loss: 0.6423 - accuracy: 0.7568 - val_loss: 1.0454 - val_accuracy: 0.6469
# Epoch 53/80
# 225/225 [==============================] - ETA: 0s - loss: 0.6341 - accuracy: 0.7639WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1205s 5s/step - loss: 0.6341 - accuracy: 0.7639 - val_loss: 1.1419 - val_accuracy: 0.6325
# Epoch 54/80
# 225/225 [==============================] - ETA: 0s - loss: 0.6237 - accuracy: 0.7655WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1164s 5s/step - loss: 0.6237 - accuracy: 0.7655 - val_loss: 1.1219 - val_accuracy: 0.6429
# Epoch 55/80
# 225/225 [==============================] - ETA: 0s - loss: 0.6074 - accuracy: 0.7752WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1171s 5s/step - loss: 0.6074 - accuracy: 0.7752 - val_loss: 1.0803 - val_accuracy: 0.6487
# Epoch 56/80
# 225/225 [==============================] - ETA: 0s - loss: 0.5873 - accuracy: 0.7805WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1164s 5s/step - loss: 0.5873 - accuracy: 0.7805 - val_loss: 1.0643 - val_accuracy: 0.6538
# Epoch 57/80
# 225/225 [==============================] - ETA: 0s - loss: 0.5808 - accuracy: 0.7851WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1172s 5s/step - loss: 0.5808 - accuracy: 0.7851 - val_loss: 1.1751 - val_accuracy: 0.6304
# Epoch 58/80
# 225/225 [==============================] - ETA: 0s - loss: 0.5704 - accuracy: 0.7893WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1175s 5s/step - loss: 0.5704 - accuracy: 0.7893 - val_loss: 1.0953 - val_accuracy: 0.6450
# Epoch 59/80
# 225/225 [==============================] - ETA: 0s - loss: 0.5480 - accuracy: 0.7973WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1169s 5s/step - loss: 0.5480 - accuracy: 0.7973 - val_loss: 1.0732 - val_accuracy: 0.6541
# Epoch 60/80
# 225/225 [==============================] - ETA: 0s - loss: 0.5403 - accuracy: 0.8002WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1166s 5s/step - loss: 0.5403 - accuracy: 0.8002 - val_loss: 1.1086 - val_accuracy: 0.6553
# Epoch 61/80
# 225/225 [==============================] - ETA: 0s - loss: 0.5269 - accuracy: 0.8034WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1165s 5s/step - loss: 0.5269 - accuracy: 0.8034 - val_loss: 1.0761 - val_accuracy: 0.6477
# Epoch 62/80
# 225/225 [==============================] - ETA: 0s - loss: 0.5188 - accuracy: 0.8096WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1172s 5s/step - loss: 0.5188 - accuracy: 0.8096 - val_loss: 1.2007 - val_accuracy: 0.6338
# Epoch 63/80
# 225/225 [==============================] - ETA: 0s - loss: 0.5140 - accuracy: 0.8087WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1167s 5s/step - loss: 0.5140 - accuracy: 0.8087 - val_loss: 1.0814 - val_accuracy: 0.6520
# Epoch 64/80
# 225/225 [==============================] - ETA: 0s - loss: 0.4983 - accuracy: 0.8159WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1165s 5s/step - loss: 0.4983 - accuracy: 0.8159 - val_loss: 1.1119 - val_accuracy: 0.6521
# Epoch 65/80
# 225/225 [==============================] - ETA: 0s - loss: 0.4851 - accuracy: 0.8197WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1170s 5s/step - loss: 0.4851 - accuracy: 0.8197 - val_loss: 1.1277 - val_accuracy: 0.6480
# Epoch 66/80
# 225/225 [==============================] - ETA: 0s - loss: 0.4812 - accuracy: 0.8223WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1171s 5s/step - loss: 0.4812 - accuracy: 0.8223 - val_loss: 1.1043 - val_accuracy: 0.6540
# Epoch 67/80
# 225/225 [==============================] - ETA: 0s - loss: 0.4713 - accuracy: 0.8258WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1166s 5s/step - loss: 0.4713 - accuracy: 0.8258 - val_loss: 1.1559 - val_accuracy: 0.6557
# Epoch 68/80
# 225/225 [==============================] - ETA: 0s - loss: 0.4670 - accuracy: 0.8271WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1163s 5s/step - loss: 0.4670 - accuracy: 0.8271 - val_loss: 1.1167 - val_accuracy: 0.6562
# Epoch 69/80
# 225/225 [==============================] - ETA: 0s - loss: 0.4535 - accuracy: 0.8331WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1162s 5s/step - loss: 0.4535 - accuracy: 0.8331 - val_loss: 1.2001 - val_accuracy: 0.6467
# Epoch 70/80
# 225/225 [==============================] - ETA: 0s - loss: 0.4429 - accuracy: 0.8403WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1170s 5s/step - loss: 0.4429 - accuracy: 0.8403 - val_loss: 1.1520 - val_accuracy: 0.6611
# Epoch 71/80
# 225/225 [==============================] - ETA: 0s - loss: 0.4327 - accuracy: 0.8423WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1164s 5s/step - loss: 0.4327 - accuracy: 0.8423 - val_loss: 1.1784 - val_accuracy: 0.6416
# Epoch 72/80
# 225/225 [==============================] - ETA: 0s - loss: 0.4293 - accuracy: 0.8423WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1159s 5s/step - loss: 0.4293 - accuracy: 0.8423 - val_loss: 1.1682 - val_accuracy: 0.6562
# Epoch 73/80
# 225/225 [==============================] - ETA: 0s - loss: 0.4154 - accuracy: 0.8488WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1176s 5s/step - loss: 0.4154 - accuracy: 0.8488 - val_loss: 1.1494 - val_accuracy: 0.6572
# Epoch 74/80
# 225/225 [==============================] - ETA: 0s - loss: 0.4053 - accuracy: 0.8518WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1230s 5s/step - loss: 0.4053 - accuracy: 0.8518 - val_loss: 1.2500 - val_accuracy: 0.6330
# Epoch 75/80
# 225/225 [==============================] - ETA: 0s - loss: 0.4055 - accuracy: 0.8524WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1272s 6s/step - loss: 0.4055 - accuracy: 0.8524 - val_loss: 1.2039 - val_accuracy: 0.6571
# Epoch 76/80
# 225/225 [==============================] - ETA: 0s - loss: 0.3912 - accuracy: 0.8563WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1165s 5s/step - loss: 0.3912 - accuracy: 0.8563 - val_loss: 1.2015 - val_accuracy: 0.6528
# Epoch 77/80
# 225/225 [==============================] - ETA: 0s - loss: 0.3777 - accuracy: 0.8617WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1167s 5s/step - loss: 0.3777 - accuracy: 0.8617 - val_loss: 1.2229 - val_accuracy: 0.6479
# Epoch 78/80
# 225/225 [==============================] - ETA: 0s - loss: 0.3841 - accuracy: 0.8591WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1330s 6s/step - loss: 0.3841 - accuracy: 0.8591 - val_loss: 1.2449 - val_accuracy: 0.6517
# Epoch 79/80
# 225/225 [==============================] - ETA: 0s - loss: 0.3736 - accuracy: 0.8628WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1245s 6s/step - loss: 0.3736 - accuracy: 0.8628 - val_loss: 1.2044 - val_accuracy: 0.6530
# Epoch 80/80
# 225/225 [==============================] - ETA: 0s - loss: 0.3727 - accuracy: 0.8634WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1208s 5s/step - loss: 0.3727 - accuracy: 0.8634 - val_loss: 1.2442 - val_accuracy: 0.6384
# CPU times: total: 3d 14h 38min 46s
# Wall time: 1d 2h 17min 13s

# %%
# serialize model structure to JSON
model_json = model.to_json()
with open("model3.json", "w") as json_file:
    json_file.write(model_json)

# %% [markdown]
# # Analyze the results

# %% [markdown]
# We got outputs at each step of the training phase. All those outputs were saved into the 'history' variable. We can use it to plot the evolution of the loss and accuracy on both the train and validation datasets:

# %%
model.evaluate(test_generator)
# Out:
# 57/57 [==============================] - 115s 2s/step - loss: 0.3091 - accuracy: 0.9185
# [0.30909228324890137, 0.9185009598731995]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['accuracy'],color='r')
plt.plot(history.history['val_accuracy'],color='b')
plt.legend(['accuraccy','validation accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()

# %%
plt.plot(history.history['loss'],color='r')
plt.plot(history.history['val_loss'],color='b')
plt.legend(['loss','validation loss'])
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
# Predict classes
y_pred = np.argmax(model.predict(test_generator), axis=1)
y_true = test_generator.classes
# Out:
# 57/57 [==============================] - 81s 1s/step

# %%
# Confusion Matrix
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
classes = ['angry','disgust','fear','happy','neutral','sad','surprise']
conf_matrix = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
# Classification Report
print(classification_report(y_true, y_pred, target_names=classes))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.90      0.89      0.90       958
#      disgust       0.92      0.91      0.91       111
#         fear       0.90      0.87      0.89      1024
#        happy       0.98      0.94      0.96      1774
#      neutral       0.90      0.92      0.91      1233
#          sad       0.86      0.92      0.89      1247
#     surprise       0.94      0.95      0.95       831
#
#     accuracy                           0.92      7178
#    macro avg       0.92      0.92      0.92      7178
# weighted avg       0.92      0.92      0.92      7178

# %%
from tensorflow.keras.utils import img_to_array
import tensorflow as tf
import numpy as np
import cv2

def load_model_from_json(json_path, weights_path):
    with open(json_path, 'r') as json_file:
        model_json = json_file.read()
    model = tf.keras.models.model_from_json(model_json)
    model.load_weights(weights_path)
    return model

model = load_model_from_json("model3.json", "model_weights.h5")

random = np.random.randint(0,150)
img_path_angry = []
img_path_disgust = []
img_path_fear = []
img_path_happy = []
img_path_neutral = []
img_path_sad = []
img_path_surprise = []

classes = ['angry','disgust','fear','happy','neutral','sad','surprise']

path = r'input2/test'

for j in os.walk(path):
    if classes[0] in j[0]:
        for i in j[2]:
            img_path_angry.append(fr'{j[0]}/{i}')
    elif classes[1] in j[0]:
        for i in j[2]:
            img_path_disgust.append(fr'{j[0]}/{i}')
    elif classes[2] in j[0]:
        for i in j[2]:
            img_path_fear.append(fr'{j[0]}/{i}')
    elif classes[3] in j[0]:
        for i in j[2]:
            img_path_happy.append(fr'{j[0]}/{i}')
    elif classes[4] in j[0]:
        for i in j[2]:
            img_path_neutral.append(fr'{j[0]}/{i}')
    elif classes[5] in j[0]:
        for i in j[2]:
            img_path_sad.append(fr'{j[0]}/{i}')
    elif classes[6] in j[0]:
        for i in j[2]:
            img_path_surprise.append(fr'{j[0]}/{i}')

# %%
def plot_pred_image():
    
    i = np.random.randint(0,100)

    img_angry = cv2.imread(img_path_angry[i])
    img_disgust = cv2.imread(img_path_disgust[i])
    img_fear = cv2.imread(img_path_fear[i])
    img_happy = cv2.imread(img_path_happy[i])
    img_neutral = cv2.imread(img_path_neutral[i])
    img_sad = cv2.imread(img_path_sad[i])
    img_surprise = cv2.imread(img_path_surprise[i])
    
    img_angry = cv2.cvtColor(img_angry,cv2.COLOR_BGR2GRAY)
    img_disgust = cv2.cvtColor(img_disgust,cv2.COLOR_BGR2GRAY)
    img_fear = cv2.cvtColor(img_fear,cv2.COLOR_BGR2GRAY)
    img_happy = cv2.cvtColor(img_happy,cv2.COLOR_BGR2GRAY)
    img_neutral = cv2.cvtColor(img_neutral,cv2.COLOR_BGR2GRAY)
    img_sad = cv2.cvtColor(img_sad,cv2.COLOR_BGR2GRAY)
    img_surprise = cv2.cvtColor(img_surprise,cv2.COLOR_BGR2GRAY)

    img_angry_pre = img_to_array(img_angry) / 255
    img_disgust_pre = img_to_array(img_disgust) / 255
    img_fear_pre = img_to_array(img_fear) / 255
    img_happy_pre = img_to_array(img_happy) / 255
    img_neutral_pre = img_to_array(img_neutral) / 255
    img_sad_pre = img_to_array(img_sad) / 255
    img_surprise_pre = img_to_array(img_surprise) / 255

    img_angry_pre = np.expand_dims(img_angry_pre,axis=0)
    img_disgust_pre = np.expand_dims(img_disgust_pre,axis=0)
    img_fear_pre = np.expand_dims(img_fear_pre,axis=0)
    img_happy_pre = np.expand_dims(img_happy_pre,axis=0)
    img_neutral_pre = np.expand_dims(img_neutral_pre,axis=0)
    img_sad_pre = np.expand_dims(img_sad_pre,axis=0)
    img_surprise_pre = np.expand_dims(img_surprise_pre,axis=0)

    pred_angry = model.predict(img_angry_pre)
    pred_disgust = model.predict(img_disgust_pre)
    pred_fear = model.predict(img_fear_pre)
    pred_happy = model.predict(img_happy_pre)
    pred_neutral = model.predict(img_neutral_pre)
    pred_sad = model.predict(img_sad_pre)
    pred_surprise = model.predict(img_surprise_pre)

    print(pred_angry[0])
    
    angry_title_pred = classes[pred_angry[0].argmax()]
        
    disgust_title_pred = classes[pred_disgust[0].argmax()]
        
    fear_title_pred = classes[pred_fear[0].argmax()]
        
    happy_title_pred = classes[pred_happy[0].argmax()]
        
    neutral_title_pred = classes[pred_sad[0].argmax()]
        
    sad_title_pred = classes[pred_neutral[0].argmax()]
        
    surprise_title_pred = classes[pred_surprise[0].argmax()]
    
    img_angry = cv2.cvtColor(img_angry,cv2.COLOR_GRAY2BGR)
    img_disgust = cv2.cvtColor(img_disgust,cv2.COLOR_GRAY2BGR)
    img_fear = cv2.cvtColor(img_fear,cv2.COLOR_GRAY2BGR)
    img_happy = cv2.cvtColor(img_happy,cv2.COLOR_GRAY2BGR)
    img_neutral = cv2.cvtColor(img_neutral,cv2.COLOR_GRAY2BGR)
    img_sad = cv2.cvtColor(img_sad,cv2.COLOR_GRAY2BGR)
    img_surprise = cv2.cvtColor(img_surprise,cv2.COLOR_GRAY2BGR)


    fig , axs = plt.subplots(3,3,figsize=[11,13])

    axs[0][0].imshow(img_angry)
    axs[0][0].set_title(f'Predict:{angry_title_pred}  orginal:Angry')

    axs[0][1].imshow(img_happy)
    axs[0][1].set_title(f'Predict:{fear_title_pred}  orginal:Happy')

    axs[0][2].imshow(img_fear)
    axs[0][2].set_title(f'Predict:{happy_title_pred}  orginal:fear')

    axs[1][0].imshow(img_neutral)
    axs[1][0].set_title(f'Predict:{neutral_title_pred}  orginal:Neutral')

    axs[1][1].imshow(img_sad)
    axs[1][1].set_title(f'Predict:{sad_title_pred}  orginal:Sad')

    axs[1][2].imshow(img_surprise)
    axs[1][2].set_title(f'Predict:{surprise_title_pred}  orginal:surprise')

    axs[2][1].imshow(img_disgust)
    axs[2][1].set_title(f'Predict:{disgust_title_pred}  orginal:disgust')

plot_pred_image()
# Out:
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# [0.67045313 0.00632837 0.04887191 0.00201739 0.12428061 0.12275152
#  0.02529704]

# %%
plot_pred_image()
# Out:
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 230ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 286ms/step
# 1/1 [==============================] - 0s 45ms/step
# [0.44710037 0.00061241 0.05808406 0.03271643 0.12204942 0.23822692
#  0.10121033]
